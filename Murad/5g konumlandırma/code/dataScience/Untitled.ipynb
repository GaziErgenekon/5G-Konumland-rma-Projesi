# %% [markdown]
# # **Veri Analizi**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("286.csv")

# %%
df.shape
# Out:
# (15425, 14)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=15425, step=1)

# %%
df.columns
# Out:
# Index(['GSM', '286', '1', '45207', '23614', '0', '31.5418', '36.7345', '4476',
#        '41', '1.1', '1353131454', '1717764615', '0.1'],
#       dtype='object')

# %%
df
# Out:
#        GSM  286  1  45207     23614  0  31.5418  36.7345   4476  41  1.1  \
# 0      GSM  286  1  45207     13966  0  31.5572  36.7216   2327  82    1
# 1      GSM  286  1  45207     36401  0  31.5301  36.7495   4506  65    1
# 2      GSM  286  1  45207     41476  0  31.5631  36.6984  96042  50    1
# 3      GSM  286  1  45207     23616  0  31.5312  36.7421   2829  81    1
# 4      GSM  286  1  45207     36436  0  31.5296  36.7490   4315  79    1
# ...    ...  ... ..    ...       ... ..      ...      ...    ...  ..  ...
# 15420  LTE  286  3  23043  40965171 -1  29.0041  40.2217   1000   3    1
# 15421  LTE  286  3  23043  40965173 -1  29.0006  40.2244   1000   3    1
# 15422  LTE  286  3  23076  41274421 -1  28.9944  40.2323   1000   3    1
# 15423  LTE  286  3  23076  41274419 -1  28.9973  40.2385   1000   2    1
# 15424  LTE  286  3  23076  41370411 -1  28.9866  40.2486   1000   7    1
#
#        1353131454  1717764615  0.1
# 0      1353131454  1717764614    0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15425 entries, 0 to 15424
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   GSM         15425 non-null  object
#  1   286         15425 non-null  int64
#  2   1           15425 non-null  int64
#  3   45207       15425 non-null  int64
#  4   23614       15425 non-null  int64
#  5   0           15425 non-null  int64
#  6   31.5418     15425 non-null  float64
#  7   36.7345     15425 non-null  float64
#  8   4476        15425 non-null  int64
#  9   41          15425 non-null  int64
#  10  1.1         15425 non-null  int64
#  11  1353131454  15425 non-null  int64
#  12  1717764615  15425 non-null  int64
#  13  0.1         15425 non-null  int64
# dtypes: float64(2), int64(11), object(1)
# memory usage: 1.6+ MB

# %%
df.describe()
# Out:
#            286             1         45207         23614             0  \
# count  15425.0  15425.000000  15425.000000  1.542500e+04  15425.000000
# mean     286.0      1.976207  28806.589173  3.574202e+07     26.419643
# std        0.0      0.830261  17750.978055  5.239893e+07     93.133132
# min      286.0      1.000000    501.000000  2.000000e+00     -1.000000
# 25%      286.0      1.000000   8765.000000  5.450528e+06     -1.000000
# 50%      286.0      2.000000  23050.000000  1.477870e+07     -1.000000
# 75%      286.0      3.000000  44403.000000  4.109957e+07     -1.000000
# max      286.0      3.000000  65342.000000  2.622778e+08    511.000000
#
#             31.5418       36.7345          4476            41      1.1  \
# count  15425.000000  15425.000000  15425.000000  15425.000000  15425.0
# mean      30.649390     39.660032   1677.611280     20.872674      1.0
# std        3.291614      1.746110   2472.481559     28.569070      0.0
# ...

# %%
df = df.drop(columns=["286", "1", "41", "1.1","1353131454", "1717764615", "0.1"])
df
# Out:
#        GSM  45207     23614  0  31.5418  36.7345   4476
# 0      GSM  45207     13966  0  31.5572  36.7216   2327
# 1      GSM  45207     36401  0  31.5301  36.7495   4506
# 2      GSM  45207     41476  0  31.5631  36.6984  96042
# 3      GSM  45207     23616  0  31.5312  36.7421   2829
# 4      GSM  45207     36436  0  31.5296  36.7490   4315
# ...    ...    ...       ... ..      ...      ...    ...
# 15420  LTE  23043  40965171 -1  29.0041  40.2217   1000
# 15421  LTE  23043  40965173 -1  29.0006  40.2244   1000
# 15422  LTE  23076  41274421 -1  28.9944  40.2323   1000
# 15423  LTE  23076  41274419 -1  28.9973  40.2385   1000
# 15424  LTE  23076  41370411 -1  28.9866  40.2486   1000
#
# [15425 rows x 7 columns]

# %%
df.duplicated().any()
# Out:
# True
